# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train=pd.read_excel("C:\\Users\\Dell\\OneDrive\\Desktop\\excel books\\flight\\Data_Train.xlsx")

# %%
train.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
test=pd.read_excel("C:\\Users\\Dell\\OneDrive\\Desktop\\excel books\\flight\\Test_set.xlsx")

# %%
flight=train.append(test)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_23288\576797343.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   flight=train.append(test)

# %%
flight
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
flight.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
flight.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# dtype: int64

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %%
flight['day']=flight['Date_of_Journey'].str.split('/').str[0].astype(int)
flight['month']=flight['Date_of_Journey'].str.split('/').str[1].astype(int)
flight['year']=flight['Date_of_Journey'].str.split('/').str[2].astype(int)

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  day              13354 non-null  int32
#  12  month            13354 non-null  int32
#  13  year             13354 non-null  int32
# dtypes: float64(1), int32(3), object(10)
# memory usage: 1.4+ MB

# %%
flight
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
flight['Arrival_Time']=flight['Arrival_Time'].str.split(' ').str[0]

# %%
flight
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20        01:10   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50        13:15   7h 25m     2 stops
# ...

# %%
flight['Arrival_hr'] = flight["Arrival_Time"].apply([lambda x:x.split(':')[0]])

# %%
flight['Arrival_min'] = flight["Arrival_Time"].apply([lambda x:x.split(':')[1]])

# %%
flight=flight.drop('Date_of_Journey',axis=1)

# %%
flight['Arrival_hr']=flight['Arrival_hr'].astype(int)
flight['Arrival_min']=flight['Arrival_min'].astype(int)

# %%
flight=flight.drop('Arrival_Time',axis=1)

# %%
flight
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
flight['Dep_hr'] = flight["Dep_Time"].apply([lambda x:x.split(':')[0]])
flight['Dep_min'] = flight["Dep_Time"].apply([lambda x:x.split(':')[1]])

# %%
flight
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
flight=flight.drop('Dep_Time',axis=1)

# %%
flight['Dep_hr']=flight['Dep_hr'].astype(int)
flight['Dep_min']=flight['Dep_min'].astype(int)

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  object
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   day              13354 non-null  int32
#  9   month            13354 non-null  int32
#  10  year             13354 non-null  int32
#  11  Arrival_hr       13354 non-null  int32
#  12  Arrival_min      13354 non-null  int32
#  13  Dep_hr           13354 non-null  int32
#  14  Dep_min          13354 non-null  int32
# dtypes: float64(1), int32(7), object(7)
# memory usage: 1.3+ MB

# %%
flight
# Out:
#                 Airline    Source Destination                  Route Duration  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR  23h 55m
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR   2h 35m
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK   6h 35m
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK  15h 15m
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK  14h 20m
#
# ...

# %%
## we can delete Route Columns since we have Total stops column

# %%
flight=flight.drop('Route',axis=1)

# %%
flight['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
flight[flight['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Duration Total_Stops Additional_Info  \
# 9039  Air India  Delhi      Cochin  23h 40m         NaN         No info
#
#        Price  day  month  year  Arrival_hr  Arrival_min  Dep_hr  Dep_min
# 9039  7480.0    6      5  2019           9           25       9       45

# %%
flight['Total_Stops']=flight['Total_Stops'].map({'non-stop':0,'2 stops':2,'1 stop':1,'3 stops':3,'4 stops':4,'nan':1})

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Duration         13354 non-null  object
#  4   Total_Stops      13353 non-null  float64
#  5   Additional_Info  13354 non-null  object
#  6   Price            10683 non-null  float64
#  7   day              13354 non-null  int32
#  8   month            13354 non-null  int32
#  9   year             13354 non-null  int32
#  10  Arrival_hr       13354 non-null  int32
#  11  Arrival_min      13354 non-null  int32
#  12  Dep_hr           13354 non-null  int32
#  13  Dep_min          13354 non-null  int32
# dtypes: float64(2), int32(7), object(5)
# memory usage: 1.2+ MB

# %%
flight['Additional_Info']
# Out:
# 0       No info
# 1       No info
# 2       No info
# 3       No info
# 4       No info
#          ...
# 2666    No info
# 2667    No info
# 2668    No info
# 2669    No info
# 2670    No info
# Name: Additional_Info, Length: 13354, dtype: object

# %%
flight.drop(6474,axis=0,inplace=True)
flight.drop(2660,axis=0,inplace=True)

# %%
flight
# Out:
#                 Airline    Source Destination Duration  Total_Stops  \
# 0                IndiGo  Banglore   New Delhi   2h 50m          0.0
# 1             Air India   Kolkata    Banglore   7h 25m          2.0
# 2           Jet Airways     Delhi      Cochin      19h          2.0
# 3                IndiGo   Kolkata    Banglore   5h 25m          1.0
# 4                IndiGo  Banglore   New Delhi   4h 45m          1.0
# ...                 ...       ...         ...      ...          ...
# 2666          Air India   Kolkata    Banglore  23h 55m          1.0
# 2667             IndiGo   Kolkata    Banglore   2h 35m          0.0
# 2668        Jet Airways     Delhi      Cochin   6h 35m          1.0
# 2669          Air India     Delhi      Cochin  15h 15m          1.0
# 2670  Multiple carriers     Delhi      Cochin  14h 20m          1.0
#
#      Additional_Info    Price  day  month  year  Arrival_hr  Arrival_min  \
# 0            No info   3897.0   24      3  2019           1           10
# ...

# %%
Dhour=flight['Duration'].str.split('h').str[0]
Dhour
# Out:
# 0        2
# 1        7
# 2       19
# 3        5
# 4        4
#         ..
# 2666    23
# 2667     2
# 2668     6
# 2669    15
# 2670    14
# Name: Duration, Length: 13351, dtype: object

# %%
flight['Duration']=Dhour.astype(int)*60

# %%
flight
# Out:
#                 Airline    Source Destination  Duration  Total_Stops  \
# 0                IndiGo  Banglore   New Delhi       120          0.0
# 1             Air India   Kolkata    Banglore       420          2.0
# 2           Jet Airways     Delhi      Cochin      1140          2.0
# 3                IndiGo   Kolkata    Banglore       300          1.0
# 4                IndiGo  Banglore   New Delhi       240          1.0
# ...                 ...       ...         ...       ...          ...
# 2666          Air India   Kolkata    Banglore      1380          1.0
# 2667             IndiGo   Kolkata    Banglore       120          0.0
# 2668        Jet Airways     Delhi      Cochin       360          1.0
# 2669          Air India     Delhi      Cochin       900          1.0
# 2670  Multiple carriers     Delhi      Cochin       840          1.0
#
#      Additional_Info    Price  day  month  year  Arrival_hr  Arrival_min  \
# ...

# %%
flight.drop('Additional_Info',axis=1,inplace=True)

# %%
flight['year'].unique()
# Out:
# array([2019])

# %%
flight
# Out:
#                 Airline    Source Destination  Duration  Total_Stops    Price  \
# 0                IndiGo  Banglore   New Delhi       120          0.0   3897.0
# 1             Air India   Kolkata    Banglore       420          2.0   7662.0
# 2           Jet Airways     Delhi      Cochin      1140          2.0  13882.0
# 3                IndiGo   Kolkata    Banglore       300          1.0   6218.0
# 4                IndiGo  Banglore   New Delhi       240          1.0  13302.0
# ...                 ...       ...         ...       ...          ...      ...
# 2666          Air India   Kolkata    Banglore      1380          1.0      NaN
# 2667             IndiGo   Kolkata    Banglore       120          0.0      NaN
# 2668        Jet Airways     Delhi      Cochin       360          1.0      NaN
# 2669          Air India     Delhi      Cochin       900          1.0      NaN
# 2670  Multiple carriers     Delhi      Cochin       840          1.0      NaN
#
# ...

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13351 entries, 0 to 2670
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Airline      13351 non-null  object
#  1   Source       13351 non-null  object
#  2   Destination  13351 non-null  object
#  3   Duration     13351 non-null  int32
#  4   Total_Stops  13350 non-null  float64
#  5   Price        10681 non-null  float64
#  6   day          13351 non-null  int32
#  7   month        13351 non-null  int32
#  8   year         13351 non-null  int32
#  9   Arrival_hr   13351 non-null  int32
#  10  Arrival_min  13351 non-null  int32
#  11  Dep_hr       13351 non-null  int32
#  12  Dep_min      13351 non-null  int32
# dtypes: float64(2), int32(8), object(3)
# memory usage: 1.0+ MB

# %%
flight['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
flight
# Out:
#                 Airline    Source Destination  Duration  Total_Stops    Price  \
# 0                IndiGo  Banglore   New Delhi       120          0.0   3897.0
# 1             Air India   Kolkata    Banglore       420          2.0   7662.0
# 2           Jet Airways     Delhi      Cochin      1140          2.0  13882.0
# 3                IndiGo   Kolkata    Banglore       300          1.0   6218.0
# 4                IndiGo  Banglore   New Delhi       240          1.0  13302.0
# ...                 ...       ...         ...       ...          ...      ...
# 2666          Air India   Kolkata    Banglore      1380          1.0      NaN
# 2667             IndiGo   Kolkata    Banglore       120          0.0      NaN
# 2668        Jet Airways     Delhi      Cochin       360          1.0      NaN
# 2669          Air India     Delhi      Cochin       900          1.0      NaN
# 2670  Multiple carriers     Delhi      Cochin       840          1.0      NaN
#
# ...

# %%
flight['Source'] =le.fit_transform(flight['Source'])  ## change to one hotted encoding
flight['Source']=flight['Source'].astype(int)

# %%
flight['Destination'] =le.fit_transform(flight['Destination']) ## change to one hotted encoding
flight['Destination'] =flight['Destination'] .astype(int)

# %%
flight
# Out:
#                 Airline  Source  Destination  Duration  Total_Stops    Price  \
# 0                IndiGo       0            5       120          0.0   3897.0
# 1             Air India       3            0       420          2.0   7662.0
# 2           Jet Airways       2            1      1140          2.0  13882.0
# 3                IndiGo       3            0       300          1.0   6218.0
# 4                IndiGo       0            5       240          1.0  13302.0
# ...                 ...     ...          ...       ...          ...      ...
# 2666          Air India       3            0      1380          1.0      NaN
# 2667             IndiGo       3            0       120          0.0      NaN
# 2668        Jet Airways       2            1       360          1.0      NaN
# 2669          Air India       2            1       900          1.0      NaN
# 2670  Multiple carriers       2            1       840          1.0      NaN
#
# ...

# %% [markdown]
# ###   Now Data is ready for modeling
